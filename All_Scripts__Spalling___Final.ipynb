# %% [markdown]
# <a href="https://colab.research.google.com/github/sam916060/PhD_Thesis/blob/main/All_Scripts__Spalling___Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RFR + Default

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Create the RandomForestRegressor with default hyperparameters
model = RandomForestRegressor(random_state=42)

# Fit the model to your data
model.fit(X_train, y_train)

# Use the model for prediction
y_pred = model.predict(X_test)

# Evaluate the model
r2_test = r2_score(y_test, y_pred)
mae_test = mean_absolute_error(y_test, y_pred)
mse_test = mean_squared_error(y_test, y_pred)
rmse_test = np.sqrt(mse_test)
mape_test = mean_absolute_percentage_error(y_test, y_pred)
medae_test = median_absolute_error(y_test, y_pred)
evs_test = explained_variance_score(y_test, y_pred)
cv_test = np.sqrt(mean_squared_error(y_test, y_pred)) / np.mean(y_test)

print("Test set performance:")
print('R2 score:', r2_test)
print('MAE:', mae_test)
print('MSE:', mse_test)
print('RMSE:', rmse_test)
print('MAPE:', mape_test)
print('MedAE:', medae_test)
print('EVS:', evs_test)
print('CV:', cv_test)

# Rest of your code remains the same (plotting, training set evaluation, etc.)
# Out:
# Test set performance:
# R2 score: 0.5308663724464192
# MAE: 1.818187128712871
# MSE: 9.215128575412539
# RMSE: 3.0356430250298763
# MAPE: 2.469747568184982
# MedAE: 1.0508999999999993
# EVS: 0.5362809374154609
# CV: 1.1647753983690259

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))

sc = ax.scatter(y_test, y_test_pred,  marker = 'o', s=40, c=y_test_pred, cmap='viridis')
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='gray')
ax.text(1, 25, r"$R^2$ = %.2f" % (r2_test), fontsize=12, bbox={
        'facecolor': 'b', 'alpha': 0.5, 'pad': 10})
ax.set_ylabel('Predicted Spalling (m)', size='14')
ax.set_xlabel('Actual Spalling (m)', size='14')

cbar = fig.colorbar(sc, shrink=1)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))

sc = ax.scatter(y_train, y_train_pred, marker = 'D', s=40, c=y_train_pred, cmap='viridis')
ax.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], '--', color='gray')
ax.text(1, 25, r"$R^2$ = %.2f" % (r2_train) , fontsize=12, bbox={
        'facecolor': 'g', 'alpha': 0.5, 'pad': 10})
ax.set_ylabel('Predicted Spalling (m)', size='14')
ax.set_xlabel('Actual Spalling (m)', size='14')

cbar = fig.colorbar(sc, shrink=1)

# %% [markdown]
# XGB + Default

# %%
pip install xgboost

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Create the XGBRegressor with default hyperparameters
model_XGB = XGBRegressor(random_state=0)

# Fit the XGBoost model to your data
model_XGB.fit(X_train, y_train)

# Use the XGBoost model for prediction
y_pred_XGB = model_XGB.predict(X_test)

# Evaluate the XGBoost model
r2_test_XGB = r2_score(y_test, y_pred_XGB)
mae_test_XGB = mean_absolute_error(y_test, y_pred_XGB)
mse_test_XGB = mean_squared_error(y_test, y_pred_XGB)
rmse_test_XGB = np.sqrt(mse_test_XGB)
mape_test_XGB = mean_absolute_percentage_error(y_test, y_pred_XGB)
medae_test_XGB = median_absolute_error(y_test, y_pred_XGB)
evs_test_XGB = explained_variance_score(y_test, y_pred_XGB)
cv_test_XGB = np.sqrt(mean_squared_error(y_test, y_pred_XGB)) / np.mean(y_test)

print("XGBoost Test set performance:")
print('R2 score:', r2_test_XGB)
print('MAE:', mae_test_XGB)
print('MSE:', mse_test_XGB)
print('RMSE:', rmse_test_XGB)
print('MAPE:', mape_test_XGB)
print('MedAE:', medae_test_XGB)
print('EVS:', evs_test_XGB)
print('CV:', cv_test_XGB)
# Out:
# XGBoost Test set performance:
# R2 score: 0.628193414711812
# MAE: 1.5743233620309005
# MSE: 7.3033466103949705
# RMSE: 2.7024704642965056
# MAPE: 1.8628611579007763
# MedAE: 0.7445384818315506
# EVS: 0.6295004472913979
# CV: 1.0369371779478282

# %%
# Assign the best model for XGBoost
best_model_XGB = model_XGB  # Assuming model_XGB is the best-performing XGBoost model

# Make predictions on training and test sets for XGBoost
y_train_pred_XGB = best_model_XGB.predict(X_train)
y_test_pred_XGB = best_model_XGB.predict(X_test)

# Evaluate the XGBoost model on training set
mae_train_XGB = mean_absolute_error(y_train, y_train_pred_XGB)
mse_train_XGB = mean_squared_error(y_train, y_train_pred_XGB)
rmse_train_XGB = np.sqrt(mse_train_XGB)
r2_train_XGB = r2_score(y_train, y_train_pred_XGB)

print("XGBoost Training set performance:")
print("MAE: {:.3f}".format(mae_train_XGB))
print("MSE: {:.3f}".format(mse_train_XGB))
print("RMSE: {:.3f}".format(rmse_train_XGB))
print("R2: {:.3f}".format(r2_train_XGB))

# Evaluate the XGBoost model on test set
mae_test_XGB = mean_absolute_error(y_test, y_test_pred_XGB)
mse_test_XGB = mean_squared_error(y_test, y_test_pred_XGB)
rmse_test_XGB = np.sqrt(mse_test_XGB)
r2_test_XGB = r2_score(y_test, y_test_pred_XGB)

print("\nXGBoost Test set performance:")
print("MAE: {:.3f}".format(mae_test_XGB))
print("MSE: {:.3f}".format(mse_test_XGB))
print("RMSE: {:.3f}".format(rmse_test_XGB))
print("R2: {:.3f}".format(r2_test_XGB))
# Out:
# XGBoost Training set performance:
# MAE: 0.178
# MSE: 0.069
# RMSE: 0.263
# R2: 0.996
#
# XGBoost Test set performance:
# MAE: 1.574
# MSE: 7.303
# RMSE: 2.702
# R2: 0.628

# %% [markdown]
# SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR  # Import SVR instead of XGBRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Create the SVR model with default hyperparameters
model_SVR = SVR()

# Fit the SVR model to your data
model_SVR.fit(X_train, y_train)

# Use the SVR model for prediction
y_pred_SVR = model_SVR.predict(X_test)

# Evaluate the SVR model
r2_test_SVR = r2_score(y_test, y_pred_SVR)
mae_test_SVR = mean_absolute_error(y_test, y_pred_SVR)
mse_test_SVR = mean_squared_error(y_test, y_pred_SVR)
rmse_test_SVR = np.sqrt(mse_test_SVR)
mape_test_SVR = mean_absolute_percentage_error(y_test, y_pred_SVR)
medae_test_SVR = median_absolute_error(y_test, y_pred_SVR)
evs_test_SVR = explained_variance_score(y_test, y_pred_SVR)
cv_test_SVR = np.sqrt(mean_squared_error(y_test, y_pred_SVR)) / np.mean(y_test)

print("SVR Test set performance:")
print('R2 score:', r2_test_SVR)
print('MAE:', mae_test_SVR)
print('MSE:', mse_test_SVR)
print('RMSE:', rmse_test_SVR)
print('MAPE:', mape_test_SVR)
print('MedAE:', medae_test_SVR)
print('EVS:', evs_test_SVR)
print('CV:', cv_test_SVR)
# Out:
# SVR Test set performance:
# R2 score: -0.11710944618858199
# MAE: 2.135650023376632
# MSE: 21.94323019033621
# RMSE: 4.684360168724883
# MAPE: 1.2318445829992528
# MedAE: 0.7254386623785458
# EVS: 0.015884626896601972
# CV: 1.797387715433643

# %% [markdown]
# RFR + RGS

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Define the parameter grid for Randomized Grid Search
param_grid = {
    'n_estimators': np.arange(50, 1001, 50),  # Number of trees in the forest
    'max_features': ['auto', 'sqrt'],  # Number of features to consider at every split
    'max_depth': np.arange(10, 110, 10),  # Maximum number of levels in tree
    'min_samples_split': np.arange(2, 21),  # Minimum number of samples required to split a node
    'min_samples_leaf': np.arange(1, 21),  # Minimum number of samples required at each leaf node
    'bootstrap': [True, False]  # Method of selecting samples for training each tree
}

# Create the RandomForestRegressor with default hyperparameters
model = RandomForestRegressor(random_state=42)

# Perform Randomized Grid Search
random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_grid,
    n_iter=100,  # Number of parameter settings that are sampled
    cv=5,  # Cross-validation folds
    random_state=42,
    n_jobs=-1  # Use all available CPU cores
)

random_search.fit(X_train, y_train)

# Get the best model from Randomized Grid Search
best_model = random_search.best_estimator_

# Use the best model for prediction
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_test)

# Calculate performance metrics for training dataset
r2_train = r2_score(y_train, y_pred_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mape_train = mean_absolute_percentage_error(y_train, y_pred_train)
medae_train = median_absolute_error(y_train, y_pred_train)
evs_train = explained_variance_score(y_train, y_pred_train)
cv_train = np.sqrt(mean_squared_error(y_train, y_pred_train)) / np.mean(y_train)

# Calculate performance metrics for testing dataset
r2_test = r2_score(y_test, y_pred_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mape_test = mean_absolute_percentage_error(y_test, y_pred_test)
medae_test = median_absolute_error(y_test, y_pred_test)
evs_test = explained_variance_score(y_test, y_pred_test)
cv_test = np.sqrt(mean_squared_error(y_test, y_pred_test)) / np.mean(y_test)

# Print the performance metrics for training dataset
print("Training set performance:")
print('R2 score:', r2_train)
print('MAE:', mae_train)
print('MSE:', mse_train)
print('RMSE:', rmse_train)
print('MAPE:', mape_train)
print('MedAE:', medae_train)
print('EVS:', evs_train)
print('CV:', cv_train)

# Print the performance metrics for testing dataset
print("\nTest set performance:")
print('R2 score:', r2_test)
print('MAE:', mae_test)
print('MSE:', mse_test)
print('RMSE:', rmse_test)
print('MAPE:', mape_test)
print('MedAE:', medae_test)
print('EVS:', evs_test)
print('CV:', cv_test)
# Out:
# Training set performance:
# R2 score: 0.9204118071334539
# MAE: 0.5711070305507447
# MSE: 1.4362530722102302
# RMSE: 1.1984377631776422
# MAPE: 0.533116789224474
# MedAE: 0.23621665421724244
# EVS: 0.9204118071334539
# CV: 0.45326409652386707
#
# Test set performance:
# R2 score: 0.5931282876099702
# MAE: 1.6945463970189536
# MSE: 7.992126172929632
# RMSE: 2.8270348729595876
# MAPE: 2.0603496055873687
# MedAE: 0.9151064075630255
# EVS: 0.5941238001192815
# CV: 1.0847325074799348

# %%
# Get the best parameters from Randomized Grid Search
best_params = random_search.best_params_

print("Best parameters found:", best_params)
# Out:
# Best parameters found: {'n_estimators': 200, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': False}

# %% [markdown]
# XGB + RGS

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from xgboost import XGBRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Define the parameter grid for Randomized Grid Search
param_grid = {
    'n_estimators': np.arange(50, 1001, 50),  # Number of trees in the forest
    'max_depth': np.arange(3, 11),  # Maximum depth of a tree
    'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5],  # Step size shrinkage used in update to prevent overfitting
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],  # Subsample ratio of the training instance
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],  # Subsample ratio of columns when constructing each tree
    'gamma': [0, 0.1, 0.2, 0.3, 0.4],  # Minimum loss reduction required to make a further partition on a leaf node of the tree
    'reg_alpha': [0, 0.001, 0.005, 0.01, 0.05],  # L1 regularization term on weights
    'reg_lambda': [0, 0.001, 0.005, 0.01, 0.05]  # L2 regularization term on weights
}

# Create the XGBRegressor with default hyperparameters
model = XGBRegressor(random_state=42)

# Perform Randomized Grid Search
random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_grid,
    n_iter=100,  # Number of parameter settings that are sampled
    cv=5,  # Cross-validation folds
    random_state=42,
    n_jobs=-1  # Use all available CPU cores
)

random_search.fit(X_train, y_train)

# Get the best model from Randomized Grid Search
best_model = random_search.best_estimator_

# Use the best model for prediction
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_test)

# Calculate performance metrics for training dataset
r2_train = r2_score(y_train, y_pred_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mape_train = mean_absolute_percentage_error(y_train, y_pred_train)
medae_train = median_absolute_error(y_train, y_pred_train)
evs_train = explained_variance_score(y_train, y_pred_train)
cv_train = np.sqrt(mean_squared_error(y_train, y_pred_train)) / np.mean(y_train)

# Calculate performance metrics for testing dataset
r2_test = r2_score(y_test, y_pred_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mape_test = mean_absolute_percentage_error(y_test, y_pred_test)
medae_test = median_absolute_error(y_test, y_pred_test)
evs_test = explained_variance_score(y_test, y_pred_test)
cv_test = np.sqrt(mean_squared_error(y_test, y_pred_test)) / np.mean(y_test)

# Print the performance metrics for training dataset
print("Training set performance:")
print('R2 score:', r2_train)
print('MAE:', mae_train)
print('MSE:', mse_train)
print('RMSE:', rmse_train)
print('MAPE:', mape_train)
print('MedAE:', medae_train)
print('EVS:', evs_train)
print('CV:', cv_train)

# Print the performance metrics for testing dataset
print("\nTest set performance:")
print('R2 score:', r2_test)
print('MAE:', mae_test)
print('MSE:', mse_test)
print('RMSE:', rmse_test)
print('MAPE:', mape_test)
print('MedAE:', medae_test)
print('EVS:', evs_test)
print('CV:', cv_test)
# Out:
# Training set performance:
# R2 score: 0.9875702624464215
# MAE: 0.3449859314668954
# MSE: 0.22430775351349702
# RMSE: 0.4736113950418603
# MAPE: 0.43918027633520057
# MedAE: 0.2443747246265412
# EVS: 0.9875702700137613
# CV: 0.17912573157563028
#
# Test set performance:
# R2 score: 0.6438976274178881
# MAE: 1.5656718262956284
# MSE: 6.994870878188817
# RMSE: 2.644781820526755
# MAPE: 1.8990059524755358
# MedAE: 0.857025728225708
# EVS: 0.6475010510654702
# CV: 1.0148020611128643

# %%
# Get the best parameters
best_params = random_search.best_params_
print("Best parameters:", best_params)
# Out:
# Best parameters: {'subsample': 0.9, 'reg_lambda': 0.005, 'reg_alpha': 0, 'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.05, 'gamma': 0.4, 'colsample_bytree': 1.0}

# %%
RFR + Optuna

# %%
pip install optuna
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.2 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)
import optuna

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Define the objective function for Optuna
def objective(trial):
    # Define the search space for the hyperparameters
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000),
        'max_features': trial.suggest_categorical('max_features', ['auto', 'sqrt']),
        'max_depth': trial.suggest_int('max_depth', 10, 110),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 21),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 21),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False])
    }

    # Create the RandomForestRegressor with the sampled hyperparameters
    model = RandomForestRegressor(**params, random_state=42)

    # Fit the model to your data
    model.fit(X_train, y_train)

    # Use the model for prediction
    y_pred = model.predict(X_test)

    # Return the negative mean squared error as the objective value to be minimized
    return -mean_squared_error(y_test, y_pred)

# Perform Optuna optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Get the best parameters found by Optuna
best_params = study.best_params

# Append default parameters to the best parameters
default_params = {
    'random_state': 42
}
best_params.update(default_params)

# Use the best parameters to train the final model
best_model = RandomForestRegressor(**best_params)
best_model.fit(X_train, y_train)

# Use the best model for prediction
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_test)

# Calculate performance metrics for training dataset
r2_train = r2_score(y_train, y_pred_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mape_train = mean_absolute_percentage_error(y_train, y_pred_train)
medae_train = median_absolute_error(y_train, y_pred_train)
evs_train = explained_variance_score(y_train, y_pred_train)
cv_train = np.sqrt(mean_squared_error(y_train, y_pred_train)) / np.mean(y_train)

# Calculate performance metrics for testing dataset
r2_test = r2_score(y_test, y_pred_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mape_test = mean_absolute_percentage_error(y_test, y_pred_test)
medae_test = median_absolute_error(y_test, y_pred_test)
evs_test = explained_variance_score(y_test, y_pred_test)
cv_test = np.sqrt(mean_squared_error(y_test, y_pred_test)) / np.mean(y_test)

# Print the best parameters found by Optuna
print("Best parameters found:", best_params)

# Print the performance metrics for training dataset
print("Training set performance:")
print('R2 score:', r2_train)
print('MAE:', mae_train)
print('MSE:', mse_train)
print('RMSE:', rmse_train)
print('MAPE:', mape_train)
print('MedAE:', medae_train)
print('EVS:', evs_train)
print('CV:', cv_train)

# Print the performance metrics for testing dataset
print("\nTest set performance:")
print('R2 score:', r2_test)
print('MAE:', mae_test)
print('MSE:', mse_test)
print('RMSE:', rmse_test)
print('MAPE:', mape_test)
print('MedAE:', medae_test)
print('EVS:', evs_test)
print('CV:', cv_test)
# Out:
# [I 2024-02-15 00:15:11,788] A new study created in memory with name: no-name-ac9575c8-d23c-4d94-b56b-ded35f1153c8
# [I 2024-02-15 00:15:13,231] Trial 0 finished with value: -16.65635866041162 and parameters: {'n_estimators': 447, 'max_features': 'sqrt', 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 9, 'bootstrap': True}. Best is trial 0 with value: -16.65635866041162.
# [I 2024-02-15 00:15:14,677] Trial 1 finished with value: -16.64098938635358 and parameters: {'n_estimators': 628, 'max_features': 'sqrt', 'max_depth': 41, 'min_samples_split': 11, 'min_samples_leaf': 16, 'bootstrap': False}. Best is trial 1 with value: -16.64098938635358.
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))

sc = ax.scatter(y_test, y_pred_test,  marker='o', s=40, c=y_pred_test, cmap='viridis')
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='gray')
ax.text(1, 25, r"$R^2$ = %.2f" % (r2_test), fontsize=12, bbox={
        'facecolor': 'b', 'alpha': 0.5, 'pad': 10})
ax.set_ylabel('Predicted Spallling (m)', size='14')
ax.set_xlabel('Actual Spalling (m)', size='14')

cbar = fig.colorbar(sc, shrink=1)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))

sc = ax.scatter(y_train, y_pred_train, marker='D', s=40, c=y_pred_train, cmap='viridis')
ax.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], '--', color='gray')
ax.text(1, 25, r"$R^2$ = %.2f" % (r2_train_XGB), fontsize=12, bbox={
        'facecolor': 'g', 'alpha': 0.5, 'pad': 10})
ax.set_ylabel('Predicted Spalling (m)', size='14')
ax.set_xlabel('Actual Spalling (m)', size='14')

cbar = fig.colorbar(sc, shrink=1)

# %% [markdown]
# XGB + Optuna

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)
import optuna
import xgboost as xgb

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Define the objective function for Optuna
def objective(trial):
    # Define the search space for the hyperparameters
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
        'random_state': 42
    }

    # Create the XGBRegressor with the sampled hyperparameters
    model = xgb.XGBRegressor(**params)

    # Fit the model to your data
    model.fit(X_train, y_train)

    # Use the model for prediction
    y_pred = model.predict(X_test)

    # Return the negative mean squared error as the objective value to be minimized
    return -mean_squared_error(y_test, y_pred)

# Perform Optuna optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Get the best parameters found by Optuna
best_params = study.best_params

# Use the best parameters to train the final model
best_model = xgb.XGBRegressor(**best_params)
best_model.fit(X_train, y_train)

# Use the best model for prediction
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_test)

# Calculate performance metrics for training dataset
r2_train = r2_score(y_train, y_pred_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mape_train = mean_absolute_percentage_error(y_train, y_pred_train)
medae_train = median_absolute_error(y_train, y_pred_train)
evs_train = explained_variance_score(y_train, y_pred_train)
cv_train = np.sqrt(mean_squared_error(y_train, y_pred_train)) / np.mean(y_train)

# Calculate performance metrics for testing dataset
r2_test = r2_score(y_test, y_pred_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mape_test = mean_absolute_percentage_error(y_test, y_pred_test)
medae_test = median_absolute_error(y_test, y_pred_test)
evs_test = explained_variance_score(y_test, y_pred_test)
cv_test = np.sqrt(mean_squared_error(y_test, y_pred_test)) / np.mean(y_test)

# Print the best parameters found by Optuna
print("Best parameters found:", best_params)

# Print the performance metrics for training dataset
print("Training set performance:")
print('R2 score:', r2_train)
print('MAE:', mae_train)
print('MSE:', mse_train)
print('RMSE:', rmse_train)
print('MAPE:', mape_train)
print('MedAE:', medae_train)
print('EVS:', evs_train)
print('CV:', cv_train)

# Print the performance metrics for testing dataset
print("\nTest set performance:")
print('R2 score:', r2_test)
print('MAE:', mae_test)
print('MSE:', mse_test)
print('RMSE:', rmse_test)
print('MAPE:', mape_test)
print('MedAE:', medae_test)
print('EVS:', evs_test)
print('CV:', cv_test)
# Out:
# [I 2024-02-15 00:22:32,723] A new study created in memory with name: no-name-2e01e06d-b284-4f27-971a-55b50442f77c
# <ipython-input-37-b3921b67c590>:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# <ipython-input-37-b3921b67c590>:31: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# <ipython-input-37-b3921b67c590>:32: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))

sc = ax.scatter(y_test, y_pred_test,  marker='o', s=40, c=y_pred_test, cmap='viridis')
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='gray')
ax.text(1, 25, r"$R^2$ = %.2f" % (r2_test), fontsize=12, bbox={
        'facecolor': 'b', 'alpha': 0.5, 'pad': 10})
ax.set_ylabel('Predicted Spallling (m)', size='14')
ax.set_xlabel('Actual Spalling (m)', size='14')

cbar = fig.colorbar(sc, shrink=1)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))

sc = ax.scatter(y_train, y_pred_train, marker='D', s=40, c=y_pred_train, cmap='viridis')
ax.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], '--', color='gray')
ax.text(1, 25, r"$R^2$ = %.2f" % (r2_train_XGB), fontsize=12, bbox={
        'facecolor': 'g', 'alpha': 0.5, 'pad': 10})
ax.set_ylabel('Predicted Spalling (m)', size='14')
ax.set_xlabel('Actual Spalling (m)', size='14')

cbar = fig.colorbar(sc, shrink=1)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)
import optuna
import xgboost as xgb

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Standardize the input features
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Define the objective function for Optuna
def objective(trial):
    # Define the search space for the hyperparameters
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
        'random_state': 42
    }

    # Create the XGBRegressor with the sampled hyperparameters
    model = xgb.XGBRegressor(**params)

    # Fit the model to your data
    model.fit(X_train, y_train)

    # Use the model for prediction
    y_pred = model.predict(X_test)

    # Return the negative mean squared error as the objective value to be minimized
    return -mean_squared_error(y_test, y_pred)

# Perform Optuna optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Get the best parameters found by Optuna
best_params = study.best_params

# Use the best parameters to train the final model
best_model = xgb.XGBRegressor(**best_params)
best_model.fit(X_train, y_train)

# Use the best model for prediction
y_pred_train1 = best_model.predict(X_train)
y_pred_test1 = best_model.predict(X_test)

# Calculate performance metrics for training dataset
r2_train = r2_score(y_train, y_pred_train1)
mae_train = mean_absolute_error(y_train, y_pred_train1)
mse_train = mean_squared_error(y_train, y_pred_train1)
rmse_train = np.sqrt(mse_train)
mape_train = mean_absolute_percentage_error(y_train, y_pred_train1)
medae_train = median_absolute_error(y_train, y_pred_train1)
evs_train = explained_variance_score(y_train, y_pred_train1)
cv_train = np.sqrt(mean_squared_error(y_train, y_pred_train1)) / np.mean(y_train)

# Calculate performance metrics for testing dataset
r2_test = r2_score(y_test, y_pred_test1)
mae_test = mean_absolute_error(y_test, y_pred_test1)
mse_test = mean_squared_error(y_test, y_pred_test1)
rmse_test = np.sqrt(mse_test)
mape_test = mean_absolute_percentage_error(y_test, y_pred_test1)
medae_test = median_absolute_error(y_test, y_pred_test1)
evs_test = explained_variance_score(y_test, y_pred_test1)
cv_test = np.sqrt(mean_squared_error(y_test, y_pred_test1)) / np.mean(y_test)

# Print the best parameters found by Optuna
print("Best parameters found:", best_params)

# Print the performance metrics for training dataset
print("Training set performance:")
print('R2 score:', r2_train)
print('MAE:', mae_train)
print('MSE:', mse_train)
print('RMSE:', rmse_train)
print('MAPE:', mape_train)
print('MedAE:', medae_train)
print('EVS:', evs_train)
print('CV:', cv_train)

# Print the performance metrics for testing dataset
print("\nTest set performance:")
print('R2 score:', r2_test)
print('MAE:', mae_test)
print('MSE:', mse_test)
print('RMSE:', rmse_test)
print('MAPE:', mape_test)
print('MedAE:', medae_test)
print('EVS:', evs_test)
print('CV:', cv_test)
# Out:
# [I 2024-02-11 01:01:54,303] A new study created in memory with name: no-name-a41ca7bc-b902-46ed-9170-e269751381a8
# <ipython-input-47-2574f637afe7>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# <ipython-input-47-2574f637afe7>:36: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# <ipython-input-47-2574f637afe7>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))

sc = ax.scatter(y_test, y_pred_test1,  marker='o', s=40, c=y_pred_test1, cmap='viridis')
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='gray')
ax.text(1, 5, r"$R^2$ = %.2f" % (r2_test), fontsize=12, bbox={
        'facecolor': 'b', 'alpha': 0.5, 'pad': 10})
ax.set_ylabel('Predicted Roughness (m/km)', size='14')
ax.set_xlabel('Actual Roughness (m/KM)', size='14')

cbar = fig.colorbar(sc, shrink=1)

# %% [markdown]
# RFR + BOT

# %%
pip install scikit-optimize
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 1.0 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade numpy scikit-learn scikit-optimize
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 30.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 22.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)
from skopt import BayesSearchCV

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Define the parameter grid for Bayesian Optimization
param_grid = {
    'n_estimators': (50, 1001),  # Number of trees in the forest
    'max_features': ['auto', 'sqrt'],  # Number of features to consider at every split
    'max_depth': (10, 110),  # Maximum number of levels in tree
    'min_samples_split': (2, 21),  # Minimum number of samples required to split a node
    'min_samples_leaf': (1, 21),  # Minimum number of samples required at each leaf node
    'bootstrap': [True, False]  # Method of selecting samples for training each tree
}


# Create the RandomForestRegressor with default hyperparameters
model = RandomForestRegressor(random_state=42)

# Perform Bayesian Optimization
bayes_search = BayesSearchCV(
    estimator=model,
    search_spaces=param_grid,
    n_iter=50,  # Number of parameter settings that are sampled
    cv=5,  # Cross-validation folds
    random_state=42,
    n_jobs=-1  # Use all available CPU cores
)

bayes_search.fit(X_train, y_train)

# Get the best model from Bayesian Optimization
best_model = bayes_search.best_estimator_

# Use the best model for prediction
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_test)

# Calculate performance metrics for training dataset
r2_train = r2_score(y_train, y_pred_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mape_train = mean_absolute_percentage_error(y_train, y_pred_train)
medae_train = median_absolute_error(y_train, y_pred_train)
evs_train = explained_variance_score(y_train, y_pred_train)
cv_train = np.sqrt(mean_squared_error(y_train, y_pred_train)) / np.mean(y_train)

# Calculate performance metrics for testing dataset
r2_test = r2_score(y_test, y_pred_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mape_test = mean_absolute_percentage_error(y_test, y_pred_test)
medae_test = median_absolute_error(y_test, y_pred_test)
evs_test = explained_variance_score(y_test, y_pred_test)
cv_test = np.sqrt(mean_squared_error(y_test, y_pred_test)) / np.mean(y_test)

# Print the performance metrics for training dataset
print("Training set performance:")
print('R2 score:', r2_train)
print('MAE:', mae_train)
print('MSE:', mse_train)
print('RMSE:', rmse_train)
print('MAPE:', mape_train)
print('MedAE:', medae_train)
print('EVS:', evs_train)
print('CV:', cv_train)

# Print the performance metrics for testing dataset
print("\nTest set performance:")
print('R2 score:', r2_test)
print('MAE:', mae_test)
print('MSE:', mse_test)
print('RMSE:', rmse_test)
print('MAPE:', mape_test)
print('MedAE:', medae_test)
print('EVS:', evs_test)
print('CV:', cv_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-6f92056f0e79> in <cell line: 49>()
#      47 )
#      48
# ---> 49 bayes_search.fit(X_train, y_train)
#      50
#      51 # Get the best model from Bayesian Optimization
#
# /usr/local/lib/python3.10/dist-packages/skopt/searchcv.py in fit(self, X, y, groups, callback, **fit_params)
#     464             self.optimizer_kwargs_ = dict(self.optimizer_kwargs)
#     465
# --> 466         super().fit(X=X, y=y, groups=groups, **fit_params)
#     467
#     468         # BaseSearchCV never ranked train scores,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1349                 )
#    1350             ):
# -> 1351                 return fit_method(estimator, *args, **kwargs)
#    1352
#    1353         return wrapper
#
# ...

# %% [markdown]
# XGB + BOT

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)
from skopt import BayesSearchCV

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Define the parameter grid for Bayesian Optimization
param_grid = {
    'n_estimators': (50, 1001),  # Number of trees in the forest
    'max_depth': (3, 11),  # Maximum depth of a tree
    'learning_rate': (1e-5, 1e-1, 'log-uniform'),  # Step size shrinkage used in update to prevent overfitting
    'subsample': (0.6, 1.0),  # Subsample ratio of the training instance
    'colsample_bytree': (0.6, 1.0),  # Subsample ratio of columns when constructing each tree
    'gamma': (0, 0.4),  # Minimum loss reduction required to make a further partition on a leaf node of the tree
    'reg_alpha': (0, 0.05),  # L1 regularization term on weights
    'reg_lambda': (0, 0.05)  # L2 regularization term on weights
}

# Create the XGBRegressor with default hyperparameters
model = XGBRegressor(random_state=42)

# Perform Bayesian Optimization
bayes_search = BayesSearchCV(
    estimator=model,
    search_spaces=param_grid,
    n_iter=50,  # Number of parameter settings that are sampled
    cv=5,  # Cross-validation folds
    random_state=42,
    n_jobs=-1  # Use all available CPU cores
)

bayes_search.fit(X_train, y_train)

# Get the best model from Bayesian Optimization
best_model = bayes_search.best_estimator_

# Use the best model for prediction
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_test)

# Calculate performance metrics for training dataset
r2_train = r2_score(y_train, y_pred_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mape_train = mean_absolute_percentage_error(y_train, y_pred_train)
medae_train = median_absolute_error(y_train, y_pred_train)
evs_train = explained_variance_score(y_train, y_pred_train)
cv_train = np.sqrt(mean_squared_error(y_train, y_pred_train)) / np.mean(y_train)

# Calculate performance metrics for testing dataset
r2_test = r2_score(y_test, y_pred_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mape_test = mean_absolute_percentage_error(y_test, y_pred_test)
medae_test = median_absolute_error(y_test, y_pred_test)
evs_test = explained_variance_score(y_test, y_pred_test)
cv_test = np.sqrt(mean_squared_error(y_test, y_pred_test)) / np.mean(y_test)

# Print the performance metrics for training dataset
print("Training set performance:")
print('R2 score:', r2_train)
print('MAE:', mae_train)
print('MSE:', mse_train)
print('RMSE:', rmse_train)
print('MAPE:', mape_train)
print('MedAE:', medae_train)
print('EVS:', evs_train)
print('CV:', cv_train)

# Print the performance metrics for testing dataset
print("\nTest set performance:")
print('R2 score:', r2_test)
print('MAE:', mae_test)
print('MSE:', mse_test)
print('RMSE:', rmse_test)
print('MAPE:', mape_test)
print('MedAE:', medae_test)
print('EVS:', evs_test)
print('CV:', cv_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f255366ef93b> in <cell line: 49>()
#      47 )
#      48
# ---> 49 bayes_search.fit(X_train, y_train)
#      50
#      51 # Get the best model from Bayesian Optimization
#
# /usr/local/lib/python3.10/dist-packages/skopt/searchcv.py in fit(self, X, y, groups, callback, **fit_params)
#     464             self.optimizer_kwargs_ = dict(self.optimizer_kwargs)
#     465
# --> 466         super().fit(X=X, y=y, groups=groups, **fit_params)
#     467
#     468         # BaseSearchCV never ranked train scores,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
# ...

# %%
# Get the best parameters
best_params = bayes_search.best_params_
print("Best parameters:", best_params)
# Out:
# Best parameters: OrderedDict([('colsample_bytree', 0.6), ('gamma', 0.4), ('learning_rate', 0.009808268504997107), ('max_depth', 7), ('n_estimators', 1001), ('reg_alpha', 0.0), ('reg_lambda', 0.0), ('subsample', 0.7433111278867033)])

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)
from skopt import BayesSearchCV

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# Create the XGBRegressor
model_XGB = XGBRegressor(random_state=0)

# Define the parameter grid for Bayesian optimization for XGBoost
param_dist_XGB = {
    'n_estimators': (100, 2000),
    'learning_rate': (0.001, 0.01, 0.1, 0.2, 0.3),
    'max_depth': [3, 4, 5, 6, 7, 8, 9],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'gamma': [0, 1, 5],
}

# Perform Bayesian optimization for XGBoost
bayesian_search_XGB = BayesSearchCV(
    model_XGB,
    param_dist_XGB,
    n_iter=100,  # adjust the number of iterations as needed
    cv=5,        # adjust the number of cross-validation folds as needed
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    random_state=42
)

# Fit the Bayesian search to the data
bayesian_search_XGB.fit(X_train, y_train)

# Get the best model from Bayesian optimization for XGBoost
best_model_XGB = bayesian_search_XGB.best_estimator_

# Use the best model for prediction for XGBoost
y_pred_XGB = best_model_XGB.predict(X_test)

# Evaluate the best model for XGBoost
r2_test_XGB = r2_score(y_test, y_pred_XGB)
mae_test_XGB = mean_absolute_error(y_test, y_pred_XGB)
mse_test_XGB = mean_squared_error(y_test, y_pred_XGB)
rmse_test_XGB = np.sqrt(mse_test_XGB)
mape_test_XGB = mean_absolute_percentage_error(y_test, y_pred_XGB)
medae_test_XGB = median_absolute_error(y_test, y_pred_XGB)
evs_test_XGB = explained_variance_score(y_test, y_pred_XGB)
cv_test_XGB = np.sqrt(mean_squared_error(y_test, y_pred_XGB)) / np.mean(y_test)

print("XGBoost Test set performance:")
print('R2 score:', r2_test_XGB)
print('MAE:', mae_test_XGB)
print('MSE:', mse_test_XGB)
print('RMSE:', rmse_test_XGB)
print('MAPE:', mape_test_XGB)
print('MedAE:', medae_test_XGB)
print('EVS:', evs_test_XGB)
print('CV:', cv_test_XGB)

# Additional evaluation on training set for XGBoost
y_train_pred_XGB = best_model_XGB.predict(X_train)
mae_train_XGB = mean_absolute_error(y_train, y_train_pred_XGB)
mse_train_XGB = mean_squared_error(y_train, y_train_pred_XGB)
rmse_train_XGB = np.sqrt(mse_train_XGB)
r2_train_XGB = r2_score(y_train, y_train_pred_XGB)

print("\nXGBoost Training set performance:")
print("MAE: {:.3f}".format(mae_train_XGB))
print("MSE: {:.3f}".format(mse_train_XGB))
print("RMSE: {:.3f}".format(rmse_train_XGB))
print("R2: {:.3f}".format(r2_train_XGB))

# Get the best parameters from the Bayesian search for XGBoost
best_params_XGB = bayesian_search_XGB.best_params_

print("Best hyperparameters for XGBoost:")
print(best_params_XGB)

# Print header for XGBoost
print("Training (XGBoost)\t\t\tTesting (XGBoost)")
print("R2\tMAE\tMSE\tRMSE\tR2\tMAE\tMSE\tRMSE")

# Print training set results for XGBoost
print("{:.3f}\t{:.3f}\t{:.3f}\t{:.3f}\t".format(r2_train_XGB, mae_train_XGB, mse_train_XGB, rmse_train_XGB), end='')

# Print testing set results for XGBoost
print("{:.3f}\t{:.3f}\t{:.3f}\t{:.3f}".format(r2_test_XGB, mae_test_XGB, mse_test_XGB, rmse_test_XGB))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-599b6ece8d00> in <cell line: 50>()
#      48
#      49 # Fit the Bayesian search to the data
# ---> 50 bayesian_search_XGB.fit(X_train, y_train)
#      51
#      52 # Get the best model from Bayesian optimization for XGBoost
#
# /usr/local/lib/python3.10/dist-packages/skopt/searchcv.py in fit(self, X, y, groups, callback, **fit_params)
#     464             self.optimizer_kwargs_ = dict(self.optimizer_kwargs)
#     465
# --> 466         super().fit(X=X, y=y, groups=groups, **fit_params)
#     467
#     468         # BaseSearchCV never ranked train scores,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1349                 )
#    1350             ):
# -> 1351                 return fit_method(estimator, *args, **kwargs)
#    1352
# ...

# %% [markdown]
# DNN + Basic

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Scaling the features
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

tf.random.set_seed(1)
# Create the DNN model
model_DNN = Sequential()
model_DNN.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model_DNN.add(Dense(64, activation='relu'))
model_DNN.add(Dense(64, activation='relu'))
model_DNN.add(Dense(1, activation='linear'))

# Compile the model
model_DNN.compile(optimizer='adam', loss='mean_squared_error')

# Fit the model to your data
model_DNN.fit(X_train, y_train, epochs=500, batch_size=32, verbose=1)

# Use the model for prediction
y_pred_DNN = model_DNN.predict(X_test).flatten()

# Evaluate the model
r2_test_DNN = r2_score(y_test, y_pred_DNN)
mae_test_DNN = mean_absolute_error(y_test, y_pred_DNN)
mse_test_DNN = mean_squared_error(y_test, y_pred_DNN)
rmse_test_DNN = np.sqrt(mse_test_DNN)
mape_test_DNN = mean_absolute_percentage_error(y_test, y_pred_DNN)
medae_test_DNN = median_absolute_error(y_test, y_pred_DNN)
evs_test_DNN = explained_variance_score(y_test, y_pred_DNN)
cv_test_DNN = np.sqrt(mean_squared_error(y_test, y_pred_DNN)) / np.mean(y_test)

print("DNN Test set performance:")
print('R2 score:', r2_test_DNN)
print('MAE:', mae_test_DNN)
print('MSE:', mse_test_DNN)
print('RMSE:', rmse_test_DNN)
print('MAPE:', mape_test_DNN)
print('MedAE:', medae_test_DNN)
print('EVS:', evs_test_DNN)
print('CV:', cv_test_DNN)

# Additional evaluation on the training set
y_train_pred_DNN = model_DNN.predict(X_train).flatten()
mae_train_DNN = mean_absolute_error(y_train, y_train_pred_DNN)
mse_train_DNN = mean_squared_error(y_train, y_train_pred_DNN)
rmse_train_DNN = np.sqrt(mse_train_DNN)
r2_train_DNN = r2_score(y_train, y_train_pred_DNN)

print("\nDNN Training set performance:")
print("MAE: {:.3f}".format(mae_train_DNN))
print("MSE: {:.3f}".format(mse_train_DNN))
print("RMSE: {:.3f}".format(rmse_train_DNN))
print("R2: {:.3f}".format(r2_train_DNN))

# Print header for DNN
print("\nTraining (DNN)\t\t\tTesting (DNN)")
print("R2\tMAE\tMSE\tRMSE\tR2\tMAE\tMSE\tRMSE")

# Print training set results for DNN
print("{:.3f}\t{:.3f}\t{:.3f}\t{:.3f}\t".format(r2_train_DNN, mae_train_DNN, mse_train_DNN, rmse_train_DNN), end='')

# Print testing set results for DNN
print("{:.3f}\t{:.3f}\t{:.3f}\t{:.3f}".format(r2_test_DNN, mae_test_DNN, mse_test_DNN, rmse_test_DNN))

# %% [markdown]
# DNN + Keras

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from kerastuner.tuners import RandomSearch

# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Scaling the features
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Define the hyperparameter search space
def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units_1', min_value=32, max_value=512, step=32), input_dim=X_train.shape[1], activation='relu'))
    for i in range(hp.Int('num_layers', 1, 5)):
        model.add(Dense(units=hp.Int(f'units_{i+2}', min_value=32, max_value=512, step=32), activation='relu'))
    model.add(Dense(1, activation='linear'))

    learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss='mean_squared_error')
    return model

# Define the tuner
tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=50,
    directory='keras_tuner_dir',
    project_name='dnn_optimization'
)

# Search for the best hyperparameter configuration
tuner.search(X_train, y_train, epochs=300, validation_data=(X_test, y_test))

# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]

# Print a summary of the best model
best_model.summary()

# Evaluate the best model
y_pred_DNN = best_model.predict(X_test).flatten()

# Evaluate the model
r2_test_DNN = r2_score(y_test, y_pred_DNN)
mae_test_DNN = mean_absolute_error(y_test, y_pred_DNN)
mse_test_DNN = mean_squared_error(y_test, y_pred_DNN)
rmse_test_DNN = np.sqrt(mse_test_DNN)
mape_test_DNN = mean_absolute_percentage_error(y_test, y_pred_DNN)
medae_test_DNN = median_absolute_error(y_test, y_pred_DNN)
evs_test_DNN = explained_variance_score(y_test, y_pred_DNN)
cv_test_DNN = np.sqrt(mean_squared_error(y_test, y_pred_DNN)) / np.mean(y_test)

print("DNN Test set performance:")
print('R2 score:', r2_test_DNN)
print('MAE:', mae_test_DNN)
print('MSE:', mse_test_DNN)
print('RMSE:', rmse_test_DNN)
print('MAPE:', mape_test_DNN)
print('MedAE:', medae_test_DNN)
print('EVS:', evs_test_DNN)
print('CV:', cv_test_DNN)

# %% [markdown]
# DNN + Optuna

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score,
)
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


# Importing the dataset
dataset = pd.read_csv('Spalling LTPP Latest1.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Scaling the features
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)
import optuna

def objective(trial):
    # Hyperparameter space
    num_layers = trial.suggest_int('num_layers', 1, 5)
    num_nodes = trial.suggest_int('num_nodes', 32, 512)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True)

    # Create the DNN model
    model = Sequential()
    model.add(Dense(num_nodes, input_dim=X_train.shape[1], activation='relu'))
    for _ in range(num_layers - 1):
        model.add(Dense(num_nodes, activation='relu'))
    model.add(Dense(1, activation='linear'))

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss='mean_squared_error')

    # Fit the model to your data
    model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=0)

    # Use the model for prediction
    y_pred = model.predict(X_test).flatten()

    # Evaluate the model
    r2 = -r2_score(y_test, y_pred)
    return r2

# Set random seed for reproducibility
seed_value = 42
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# Create study and optimize
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

# Get the best hyperparameters
best_params = study.best_params
best_num_layers = best_params['num_layers']
best_num_nodes = best_params['num_nodes']
best_learning_rate = best_params['learning_rate']

# Print the best hyperparameters
print("Best Hyperparameters:")
print("Number of Layers:", best_num_layers)
print("Number of Nodes:", best_num_nodes)
print("Learning Rate:", best_learning_rate)

# Build the final model with the best hyperparameters
final_model = Sequential()
final_model.add(Dense(best_num_nodes, input_dim=X_train.shape[1], activation='relu'))
for _ in range(best_num_layers - 1):
    final_model.add(Dense(best_num_nodes, activation='relu'))
final_model.add(Dense(1, activation='linear'))
final_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=best_learning_rate), loss='huber')

# Fit the final model to your data
final_model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)

# Use the final model for prediction
y_pred_final = final_model.predict(X_test).flatten()

# Evaluate the final model
r2_final = r2_score(y_test, y_pred_final)

# Print the R2 score for the final model
print("\nFinal Model Test set performance (after optimization):")
print('R2 score:', r2_final)
